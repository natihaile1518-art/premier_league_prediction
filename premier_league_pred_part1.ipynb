# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ```python
# seasons_data = {
#    "2016-17": table_2016_17,
#    "2017-18": table_2017_18,
#    "2018-19": table_2018_19
# }
# ```

# %%
# All seasons data with exact features: Rk, Squad, MP, W, D, L, GF, GA, GD, Pts, Season
# first of all i have 11 features 
# Since fbref.com is actively blocking scraping attemptsi use this method to countinue my project
seasons_data = {
    '2016-17': {
        'Rk': list(range(1, 21)),# used to genarate 20 number range(start, stop)
        'Squad': ['Chelsea', 'Tottenham', 'Man City', 'Liverpool', 'Arsenal', 'Man United',
                  'Everton', 'Southampton', 'Bournemouth', 'West Brom', 'West Ham', 'Leicester City',
                  'Stoke City', 'Crystal Palace', 'Swansea City', 'Burnley', 'Watford', 'Hull City',
                  'Middlesbrough', 'Sunderland'],
        'MP': [38]*20, 'W': [30,26,23,22,23,18,17,12,12,12,12,12,11,12,12,11,11,9,5,6],
        'D': [3,8,9,10,6,15,10,10,9,9,9,8,9,5,5,7,8,7,13,6],
        'L': [5,4,6,6,9,5,11,16,17,17,17,18,18,21,21,20,19,22,20,26],
        'GF': [85,86,80,78,77,54,62,41,55,43,47,48,41,50,45,39,40,37,27,29],
        'GA': [33,26,39,42,44,29,44,48,67,51,64,63,56,63,70,55,68,80,53,69],
        'GD': [52,60,41,36,33,25,18,-7,-12,-8,-17,-15,-15,-13,-25,-16,-28,-43,-26,-40],
        'Pts': [93,86,78,76,75,69,61,46,46,45,45,44,42,41,41,40,40,34,28,24]
    },
    '2017-18': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Man United', 'Tottenham', 'Liverpool', 'Chelsea', 'Arsenal',
                  'Burnley', 'Everton', 'Leicester City', 'Newcastle', 'Crystal Palace', 'Bournemouth',
                  'West Ham', 'Watford', 'Brighton', 'Huddersfield', 'Southampton', 'Swansea City',
                  'Stoke City', 'West Brom'],
        'MP': [38]*20, 'W': [32,25,23,21,21,19,14,13,12,12,11,11,10,11,9,9,7,8,7,6],
        'D': [4,6,8,12,7,6,12,10,11,8,11,11,12,8,9,10,15,9,12,13],
        'L': [2,7,7,5,10,13,12,15,15,18,16,16,16,19,20,19,16,21,19,19],
        'GF': [106,68,74,84,62,74,36,44,56,39,45,45,48,44,34,28,37,28,35,31],
        'GA': [27,28,36,38,38,51,39,58,60,47,55,61,68,64,54,58,56,56,68,56],
        'GD': [79,40,38,46,24,23,-3,-14,-4,-8,-10,-16,-20,-20,-20,-30,-19,-28,-33,-25],
        'Pts': [100,81,77,75,70,63,54,49,47,44,44,44,42,41,36,37,36,33,33,31]
    },
    '2018-19': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Liverpool', 'Chelsea', 'Tottenham', 'Arsenal', 'Man United',
                  'Wolves', 'Everton', 'Leicester City', 'West Ham', 'Watford', 'Crystal Palace',
                  'Newcastle', 'Bournemouth', 'Burnley', 'Southampton', 'Brighton', 'Cardiff City',
                  'Fulham', 'Huddersfield'],
        'MP': [38]*20, 'W': [32,30,21,23,21,19,16,15,15,15,14,14,12,13,11,9,9,10,7,3],
        'D': [2,7,9,2,7,9,9,9,7,7,8,7,9,6,7,12,9,4,5,7],
        'L': [4,1,8,13,10,10,13,14,16,16,16,17,17,19,20,17,20,24,26,28],
        'GF': [95,89,63,67,73,65,47,54,51,52,52,51,42,56,45,45,35,34,34,22],
        'GA': [23,22,39,39,51,54,46,46,48,55,59,53,48,70,68,65,60,69,81,76],
        'GD': [72,67,24,28,22,11,1,8,3,-3,-7,-2,-6,-14,-23,-20,-25,-35,-47,-54],
        'Pts': [98,97,72,71,70,66,57,54,52,52,50,49,45,45,40,39,36,34,26,16]
    },
    '2019-20': {
        'Rk': list(range(1, 21)),
        'Squad': ['Liverpool', 'Man City', 'Man United', 'Chelsea', 'Leicester City', 'Tottenham',
                  'Wolves', 'Arsenal', 'Sheffield United', 'Burnley', 'Southampton', 'Everton',
                  'Newcastle', 'Crystal Palace', 'Brighton', 'West Ham', 'Aston Villa', 'Bournemouth',
                  'Watford', 'Norwich City'],
        'MP': [38]*20, 'W': [32,26,18,20,18,16,15,14,14,15,15,13,11,11,9,10,9,9,9,5],
        'D': [3,3,12,6,8,11,14,14,12,9,7,10,11,10,14,9,8,7,8,6],
        'L': [3,9,8,12,12,11,9,10,12,14,16,15,16,17,15,19,21,22,21,27],
        'GF': [85,102,66,69,67,61,51,56,39,43,51,44,38,31,39,49,41,40,36,26],
        'GA': [33,35,36,54,41,47,40,48,39,50,60,56,58,50,54,62,67,65,64,75],
        'GD': [52,67,30,15,26,14,11,8,0,-7,-9,-12,-20,-19,-15,-13,-26,-25,-28,-49],
        'Pts': [99,81,66,66,62,59,59,56,54,54,52,49,44,43,41,39,35,34,34,21]
    },
    '2020-21': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Man United', 'Liverpool', 'Chelsea', 'Leicester City', 'West Ham',
                  'Tottenham', 'Arsenal', 'Leeds United', 'Everton', 'Aston Villa', 'Newcastle',
                  'Wolves', 'Crystal Palace', 'Southampton', 'Brighton', 'Burnley', 'Fulham',
                  'West Brom', 'Sheffield United'],
        'MP': [38]*20, 'W': [27,21,20,19,20,19,18,18,18,17,16,12,12,12,12,9,10,5,5,7],
        'D': [5,11,9,10,6,8,8,7,5,8,7,9,9,8,7,14,9,13,11,2],
        'L': [6,6,9,9,12,11,12,13,15,13,15,17,17,18,19,15,19,20,22,29],
        'GF': [83,73,68,58,68,62,68,55,62,47,55,46,36,41,47,40,33,27,35,20],
        'GA': [32,44,42,36,50,47,45,39,54,48,46,62,52,66,68,46,55,53,76,63],
        'GD': [51,29,26,22,18,15,23,16,8,-1,9,-16,-16,-25,-21,-6,-22,-26,-41,-43],
        'Pts': [86,74,69,67,66,65,62,61,59,59,55,45,45,44,43,41,39,28,26,23]
    },
    '2021-22': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Liverpool', 'Chelsea', 'Tottenham', 'Arsenal', 'Man United',
                  'West Ham', 'Leicester City', 'Brighton', 'Wolves', 'Newcastle', 'Crystal Palace',
                  'Brentford', 'Aston Villa', 'Southampton', 'Everton', 'Leeds United', 'Burnley',
                  'Watford', 'Norwich City'],
        'MP': [38]*20, 'W': [29,28,21,22,22,16,16,14,12,15,13,11,13,13,9,11,9,7,6,5],
        'D': [6,8,11,5,3,10,8,9,15,6,10,15,7,5,13,6,9,14,7,7],
        'L': [3,2,6,11,13,12,14,15,11,17,15,12,18,20,16,21,20,17,25,26],
        'GF': [99,94,76,69,61,57,60,62,42,38,44,50,48,52,43,43,42,34,34,23],
        'GA': [26,26,33,40,48,57,51,59,44,43,62,46,56,71,67,66,79,53,77,84],
        'GD': [73,68,43,29,13,0,9,3,-2,-5,-18,4,-8,-19,-24,-23,-37,-19,-43,-61],
        'Pts': [93,92,74,71,69,58,56,51,51,51,49,48,46,45,40,39,38,35,25,22]
    },
    '2022-23': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Arsenal', 'Man United', 'Newcastle', 'Liverpool', 'Brighton',
                  'Aston Villa', 'Tottenham', 'Brentford', 'Fulham', 'Crystal Palace', 'Chelsea',
                  'Wolves', 'West Ham', 'Bournemouth', 'Nottm Forest', 'Everton', 'Leicester City',
                  'Leeds United', 'Southampton'],
        'MP': [38]*20, 'W': [28,26,23,19,19,18,18,18,15,15,11,11,11,11,11,9,8,9,7,6],
        'D': [5,6,6,14,10,6,7,6,14,7,12,11,8,10,9,11,12,7,10,7],
        'L': [5,6,9,5,9,14,13,14,9,16,15,16,19,17,18,18,18,22,21,25],
        'GF': [94,88,58,68,75,72,51,70,58,55,40,38,31,42,37,38,34,51,48,36],
        'GA': [33,43,43,33,47,53,46,63,46,53,49,47,58,55,71,68,57,68,78,73],
        'GD': [61,45,15,35,28,19,5,7,12,2,-9,-9,-27,-13,-34,-30,-23,-17,-30,-37],
        'Pts': [89,84,75,71,67,62,61,60,59,52,45,44,41,40,39,38,36,34,31,25]
    },
    '2023-24': {
        'Rk': list(range(1, 21)),
        'Squad': ['Man City', 'Arsenal', 'Liverpool', 'Aston Villa', 'Tottenham', 'Chelsea',
                  'Newcastle', 'Man United', 'West Ham', 'Crystal Palace', 'Brighton', 'Bournemouth',
                  'Fulham', 'Wolves', 'Everton', 'Brentford', 'Nottm Forest', 'Luton Town',
                  'Burnley', 'Sheffield United'],
        'MP': [38]*20, 'W': [28,28,24,20,20,18,18,18,14,13,12,13,13,14,13,10,9,6,5,3],
        'D': [7,5,8,8,6,9,6,6,10,10,14,9,8,5,9,9,9,7,9,7],
        'L': [3,5,6,10,12,11,14,14,14,15,12,16,17,19,16,19,20,25,24,28],
        'GF': [96,91,86,76,74,77,85,57,60,57,55,54,55,50,40,56,49,52,41,35],
        'GA': [34,29,41,61,61,63,62,58,74,58,62,67,61,65,51,65,67,85,78,104],
        'GD': [62,62,45,15,13,14,23,-1,-14,-1,-7,-13,-6,-15,-11,-9,-18,-33,-37,-69],
        'Pts': [91,89,82,68,66,63,60,60,52,49,48,48,47,46,48,39,32,26,24,16]
    },
    '2024-25': {
        'Rk': list(range(1, 21)),
        'Squad': ['Liverpool', 'Arsenal', 'Man City', 'Chelsea', 'Newcastle', 'Aston Villa',
                  'Nottm Forest', 'Brighton', 'Bournemouth', 'Brentford', 'Fulham', 'Crystal Palace',
                  'Everton', 'West Ham', 'Man United', 'Wolves', 'Tottenham', 'Leicester City',
                  'Ipswich Town', 'Southampton'],
        'MP': [38]*20, 'W': [25,24,23,20,19,19,19,17,16,16,15,15,14,12,12,12,11,7,6,3],
        'D': [9,8,7,9,10,8,7,10,12,12,9,8,6,11,6,6,5,11,10,6],
        'L': [4,6,8,9,9,11,12,11,10,10,14,15,18,15,20,20,22,20,22,29],
        'GF': [84,81,76,70,68,64,62,61,58,58,54,53,48,43,42,42,38,51,36,28],
        'GA': [39,46,48,49,47,57,50,54,46,49,54,53,50,59,52,57,39,68,68,88],
        'GD': [45,35,28,21,21,7,12,7,12,9,0,0,-2,-16,-10,-15,-1,-17,-32,-60],
        'Pts': [84,80,76,69,67,65,64,61,60,60,54,53,48,47,42,42,38,32,28,15]
    },
    '2025-26': {
        'Rk': list(range(1, 21)),
        'Squad': ['Arsenal', 'Man City', 'Aston Villa', 'Man United', 'Chelsea', 'Liverpool',
                  'Brentford', 'Everton', 'Bournemouth', 'Newcastle', 'Sunderland', 'Fulham',
                  'Crystal Palace', 'Brighton', 'Leeds United', 'Tottenham', 'Nottm Forest',
                  'West Ham', 'Burnley', 'Wolves'],
        'MP': [26]*20, 'W': [17,16,15,12,12,12,12,10,9,10,9,10,8,7,7,7,7,6,4,1],
        'D': [6,5,5,9,8,6,4,7,10,6,9,4,8,10,9,8,6,6,6,6],
        'L': [3,5,6,5,6,8,10,9,7,10,8,12,10,9,10,11,13,14,16,19],
        'GF': [50,54,37,47,47,41,40,29,43,37,27,35,28,34,36,36,25,32,28,16],
        'GA': [18,24,27,37,30,35,35,30,45,37,30,40,32,34,45,37,38,49,51,48],
        'GD': [32,30,10,10,17,6,5,-1,-2,0,-3,-5,-4,0,-9,-1,-13,-17,-23,-32],
        'Pts': [57,53,50,45,44,42,40,37,37,36,36,34,32,31,30,29,27,24,18,9]
    }
}

# Create DataFrames and add Pts/MP
# adding pts/mp is important for my machine learning journey because i use it for feature engineering
all_dfs = [] # create an empty list and store each season data frame into this list
for season, data in seasons_data.items(): # so this line put the label into season and content on the data
    df = pd.DataFrame(data)# turn data into dataframes(spreadsheet)
    ## so in general those above three steps are just create a dataframe from a dictionary df['Pts/MP'] = (df['Pts'] / df['MP']).round(2) # create anew column called pts/mp and calculate it
    df['Season'] = season # create a new column called season and add season value onit
    all_dfs.append(df) # add the df value into the empty list
    print(f"✓ {season}: {df.iloc[0]['Squad']} ({df.iloc[0]['Pts']} pts)")
    # what is f"":means insert variable values inside this string
    # What is df.iloc[0]? it means select row by postion or index number
    # df.iloc[0]['Squad'] from that row, get the value in column "Squad"
# Separate historical and current
df_historical = pd.concat(all_dfs[:-1], ignore_index=True)  # 2016-2025
df_current = all_dfs[-1] # 2025-26 -1 indicate the last item in the list -2 also describe the secound last element
df_complete = pd.concat(all_dfs, ignore_index=True)
# what happens if we remove ignore_index=True each season dataframe will have its own r0w number
# Save files
df_historical.to_csv('data/premier_league_2016_2025_historical.csv', index=False)
df_current.to_csv('data/premier_league_2025_26_current.csv', index=False)
# index=True → save row numbers into file
# index=False → do NOT save row numbers so our result look like Squad, Pts
#                                                               Chelsea, 93
# what if we use index=true?
# Out:
# ✓ 2016-17: Chelsea (93 pts)
# ✓ 2017-18: Man City (100 pts)
# ✓ 2018-19: Man City (98 pts)
# ✓ 2019-20: Liverpool (99 pts)
# ✓ 2020-21: Man City (86 pts)
# ✓ 2021-22: Man City (93 pts)
# ✓ 2022-23: Man City (89 pts)
# ✓ 2023-24: Man City (91 pts)
# ✓ 2024-25: Liverpool (84 pts)
# ✓ 2025-26: Arsenal (57 pts)

# %% [markdown]
# ```
# index=False → do NOT save row numbers so our result look like Squad, Pts
#                                                               Chelsea, 93
# what if we use index=true?,Squad,Pts
#                           0,Chelsea,93
#                            1,Arsenal,89  so this add another problem when we load the data again my
# data frame will look like Unnamed: 0	Squad	Pts
#                                0   0 Chelsea	 93
# ###
# so it is better use index=False
# ```

# %% [markdown]
# ```
# df_historical = pd.concat(all_dfs[:-1], ignore_index=True)  # 2016-2025
# df_current = all_dfs[-1]  # 2025-26
# df_complete = pd.concat(all_dfs, ignore_index=True) explain this code
#
# So what does all_dfs[:-1] mean?
#
# It starts at index 0 (first season)
#
# Stops before -1, which is the last season
# ```

# %%
import pandas as pd

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

df = pd.read_csv('data/premier_league_complete_2016_2026.csv')
print(df.head(20))
# Out:
#     Rk           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP   Season
# 0    1         Chelsea  38  30   3   5  85  33  52   93    2.45  2016-17
# 1    2       Tottenham  38  26   8   4  86  26  60   86    2.26  2016-17
# 2    3        Man City  38  23   9   6  80  39  41   78    2.05  2016-17
# 3    4       Liverpool  38  22  10   6  78  42  36   76    2.00  2016-17
# 4    5         Arsenal  38  23   6   9  77  44  33   75    1.97  2016-17
# 5    6      Man United  38  18  15   5  54  29  25   69    1.82  2016-17
# 6    7         Everton  38  17  10  11  62  44  18   61    1.61  2016-17
# 7    8     Southampton  38  12  10  16  41  48  -7   46    1.21  2016-17
# 8    9     Bournemouth  38  12   9  17  55  67 -12   46    1.21  2016-17
# 9   10       West Brom  38  12   9  17  43  51  -8   45    1.18  2016-17
# 10  11        West Ham  38  12   9  17  47  64 -17   45    1.18  2016-17
# 11  12  Leicester City  38  12   8  18  48  63 -15   44    1.16  2016-17
# ...
